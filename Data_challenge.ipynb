# %%
import pandas as pd
import numpy as np

# %%
print('hello world')
# Out:
# hello world

# %%
t1 = pd.read_csv('/Users/pangrui/Desktop/C1_python/data/Tickets.csv', header = 0)
t1.head()
# Out:
#         ITIN_ID  YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR  \
# 0  201912723049  2019        1    ABI             US               TX
# 1  201912723085  2019        1    ABI             US               TX
# 2  201912723491  2019        1    ABI             US               TX
# 3  201912723428  2019        1    ABI             US               TX
# 4  201912723509  2019        1    ABI             US               TX
#
#   ORIGIN_STATE_NM  ROUNDTRIP REPORTING_CARRIER  PASSENGERS ITIN_FARE  \
# 0           Texas        1.0                MQ         1.0     736.0
# 1           Texas        1.0                MQ         1.0     570.0
# 2           Texas        1.0                MQ         1.0     564.0
# 3           Texas        1.0                MQ         1.0     345.0
# 4           Texas        0.0                MQ         1.0     309.0
#
#   DESTINATION
# 0         DAB
# 1         COS
# 2         MCO
# 3         LGA
# 4         MGM

# %%
t2 =t1.iloc[int((t1.shape[0]+1)/2):,]
t2.head()
# Out:
#              ITIN_ID  YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR  \
# 583643  201915200756  2019        1    MCI             US               MO
# 583644   20191612845  2019        1    MCI             US               MO
# 583645  201911177475  2019        1    MCI             US               MO
# 583646  201914642377  2019        1    MCI             US               MO
# 583647  201914638783  2019        1    MCI             US               MO
#
#        ORIGIN_STATE_NM  ROUNDTRIP REPORTING_CARRIER  PASSENGERS ITIN_FARE  \
# 583643        Missouri        1.0                YX         1.0     478.0
# 583644        Missouri        0.0                AA         1.0     398.0
# 583645        Missouri        1.0                AS         4.0     231.0
# 583646        Missouri        1.0                WN         2.0     352.0
# 583647        Missouri        1.0                WN         1.0     701.0
#
#        DESTINATION
# 583643         ORD
# 583644         DFW
# 583645         SEA
# 583646         FLL
# 583647         PHX

# %%
t3 = t1.iloc[:int((t1.shape[0]+1)/2),]
t3.tail()
# Out:
#              ITIN_ID  YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR  \
# 583638  201914640688  2019        1    MCI             US               MO
# 583639  201914636610  2019        1    MCI             US               MO
# 583640  201914628838  2019        1    MCI             US               MO
# 583641  201914635868  2019        1    MCI             US               MO
# 583642  201914628853  2019        1    MCI             US               MO
#
#        ORIGIN_STATE_NM  ROUNDTRIP REPORTING_CARRIER  PASSENGERS ITIN_FARE  \
# 583638        Missouri        1.0                WN         1.0     413.0
# 583639        Missouri        1.0                WN         1.0     713.0
# 583640        Missouri        1.0                WN         1.0     618.0
# 583641        Missouri        1.0                WN         1.0     682.0
# 583642        Missouri        1.0                WN         1.0      11.0
#
#        DESTINATION
# 583638         CLE
# 583639         MDW
# 583640         CMH
# 583641         CLT
# 583642         DCA

# %%
t1.shape[0] == t2.shape[0] + t3.shape[0]
# Out:
# True

# %%
t2.to_csv('/Users/pangrui/Desktop/C1_python/data/Tickets1.csv', index= False)
t3.to_csv('/Users/pangrui/Desktop/C1_python/data/Tickets2.csv', index= False)

# %%
def seperate_csv(file_name):
    t1 = pd.read_csv(f'/Users/pangrui/Desktop/C1_python/data/{file_name}.csv', header = 0)
    if t1.shape[0] % 2 == 1 :
        t2 =t1.iloc[int((t1.shape[0]+1)/2):,]
        t3 = t1.iloc[:int((t1.shape[0]+1)/2),]
    else :
        t2 =t1.iloc[int((t1.shape[0])/2):,]
        t3 = t1.iloc[:int((t1.shape[0])/2),]

    if t1.shape[0] == t2.shape[0] + t3.shape[0]:
        t2.to_csv(f'/Users/pangrui/Desktop/C1_python/data/{file_name}1.csv', index= False)
        t3.to_csv(f'/Users/pangrui/Desktop/C1_python/data/{file_name}2.csv', index= False)   
        print('down')

# %%
seperate_csv('Flights')
seperate_csv('Tickets')
# Out:
# /var/folders/_m/qzwv1wg53p96cq3kbx83vxbw0000gn/T/ipykernel_17308/781862620.py:2: DtypeWarning: Columns (3,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   t1 = pd.read_csv(f'/Users/pangrui/Desktop/C1_python/data/{file_name}.csv', header = 0)
# down
